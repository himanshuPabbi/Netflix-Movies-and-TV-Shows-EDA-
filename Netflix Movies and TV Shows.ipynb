# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("netflix_titles.csv")

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df=df.dropna()

# %%
df
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5332 entries, 7 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5332 non-null   object
#  1   type          5332 non-null   object
#  2   title         5332 non-null   object
#  3   director      5332 non-null   object
#  4   cast          5332 non-null   object
#  5   country       5332 non-null   object
#  6   date_added    5332 non-null   object
#  7   release_year  5332 non-null   int64
#  8   rating        5332 non-null   object
#  9   duration      5332 non-null   object
#  10  listed_in     5332 non-null   object
#  11  description   5332 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 541.5+ KB

# %%
df.describe()
# Out:
#        release_year
# count   5332.000000
# mean    2012.742123
# std        9.625831
# min     1942.000000
# 25%     2011.000000
# 50%     2016.000000
# 75%     2018.000000
# max     2021.000000

# %%
df=df.drop("show_id",axis=1)

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#          type                          title             director  \
# 0       Movie                        Sankofa         Haile Gerima
# 1     TV Show  The Great British Baking Show      Andy Devonshire
# 2       Movie                   The Starling       Theodore Melfi
# 3       Movie                   Je Suis Karl  Christian Schwochow
# 4       Movie                          Jeans           S. Shankar
# ...       ...                            ...                  ...
# 5327    Movie                        Zinzana      Majid Al Ansari
# 5328    Movie                         Zodiac        David Fincher
# 5329    Movie                     Zombieland      Ruben Fleischer
# 5330    Movie                           Zoom         Peter Hewitt
# 5331    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# 0     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 1     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %%
sns.boxplot(df['release_year'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='release_year'>

# %%
q1=df['release_year'].quantile(0.25)

# %%
q3=df['release_year'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['release_year']>lower) & (df['release_year']<upper)]

# %%
df
# Out:
#          type                          title             director  \
# 1     TV Show  The Great British Baking Show      Andy Devonshire
# 2       Movie                   The Starling       Theodore Melfi
# 3       Movie                   Je Suis Karl  Christian Schwochow
# 5       Movie                      Grown Ups         Dennis Dugan
# 6       Movie                     Dark Skies        Scott Stewart
# ...       ...                            ...                  ...
# 5327    Movie                        Zinzana      Majid Al Ansari
# 5328    Movie                         Zodiac        David Fincher
# 5329    Movie                     Zombieland      Ruben Fleischer
# 5330    Movie                           Zoom         Peter Hewitt
# 5331    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# 1     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 2     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# ...

# %%
df['date_added']=pd.to_datetime(df['date_added'])
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_24696\3736733135.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date_added']=pd.to_datetime(df['date_added'])

# %%
df
# Out:
#          type                          title             director  \
# 1     TV Show  The Great British Baking Show      Andy Devonshire
# 2       Movie                   The Starling       Theodore Melfi
# 3       Movie                   Je Suis Karl  Christian Schwochow
# 5       Movie                      Grown Ups         Dennis Dugan
# 6       Movie                     Dark Skies        Scott Stewart
# ...       ...                            ...                  ...
# 5327    Movie                        Zinzana      Majid Al Ansari
# 5328    Movie                         Zodiac        David Fincher
# 5329    Movie                     Zombieland      Ruben Fleischer
# 5330    Movie                           Zoom         Peter Hewitt
# 5331    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# 1     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 2     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# ...

# %%
df['Month_added']=df['date_added'].dt.month
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_24696\1285822914.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Month_added']=df['date_added'].dt.month

# %%
df['Year_added']=df['date_added'].dt.year
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_24696\3998365902.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year_added']=df['date_added'].dt.year

# %%
df['Day_added']=df['date_added'].dt.day
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_24696\3735904798.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Day_added']=df['date_added'].dt.day

# %%
df['Day_of_week_added']=df['date_added'].dt.day_of_week
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_24696\2019021294.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Day_of_week_added']=df['date_added'].dt.day_of_week

# %%
df['quarter'] = pd.PeriodIndex(df.date_added, freq='Q')
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_24696\1258175703.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['quarter'] = pd.PeriodIndex(df.date_added, freq='Q')

# %%
df=df.drop("date_added",axis=1)

# %%
df
# Out:
#          type                          title             director  \
# 1     TV Show  The Great British Baking Show      Andy Devonshire
# 2       Movie                   The Starling       Theodore Melfi
# 3       Movie                   Je Suis Karl  Christian Schwochow
# 5       Movie                      Grown Ups         Dennis Dugan
# 6       Movie                     Dark Skies        Scott Stewart
# ...       ...                            ...                  ...
# 5327    Movie                        Zinzana      Majid Al Ansari
# 5328    Movie                         Zodiac        David Fincher
# 5329    Movie                     Zombieland      Ruben Fleischer
# 5330    Movie                           Zoom         Peter Hewitt
# 5331    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# 1     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 2     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# ...

# %%
sns.countplot(df['type'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
sns.countplot(df['quarter'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df['release_year'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(x=df['release_year'],hue=df['type'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x=df['quarter'],hue=df['type'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(df['Month_added'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Month_added', ylabel='count'>

# %%
sns.countplot(x=df['Month_added'],hue=df['type'])
# Out:
# <AxesSubplot:xlabel='Month_added', ylabel='count'>

# %%
sns.countplot(df['Year_added'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Year_added', ylabel='count'>

# %%
sns.countplot(df['Day_of_week_added'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Day_of_week_added', ylabel='count'>

# %%
sns.countplot(df['Day_of_week_added'],hue=df['type'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Day_of_week_added', ylabel='count'>

# %%
sns.countplot(x=df['Year_added'],hue=df['type'])
# Out:
# <AxesSubplot:xlabel='Year_added', ylabel='count'>

# %%
sns.countplot(df['Day_added'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Day_added', ylabel='count'>

# %%
sns.countplot(x=df['Day_added'],hue=df['type'])
# Out:
# <AxesSubplot:xlabel='Day_added', ylabel='count'>

# %% [markdown]
# # Top 10 Country with highest number of movies release

# %%
df
# Out:
#          type                          title             director  \
# 1     TV Show  The Great British Baking Show      Andy Devonshire
# 2       Movie                   The Starling       Theodore Melfi
# 3       Movie                   Je Suis Karl  Christian Schwochow
# 5       Movie                      Grown Ups         Dennis Dugan
# 6       Movie                     Dark Skies        Scott Stewart
# ...       ...                            ...                  ...
# 5327    Movie                        Zinzana      Majid Al Ansari
# 5328    Movie                         Zodiac        David Fincher
# 5329    Movie                     Zombieland      Ruben Fleischer
# 5330    Movie                           Zoom         Peter Hewitt
# 5331    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# 1     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 2     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# ...

# %%
new_df=df.groupby("type").get_group("Movie")

# %%
new_df
# Out:
#        type         title             director  \
# 2     Movie  The Starling       Theodore Melfi
# 3     Movie  Je Suis Karl  Christian Schwochow
# 5     Movie     Grown Ups         Dennis Dugan
# 6     Movie    Dark Skies        Scott Stewart
# 7     Movie      Paranoia       Robert Luketic
# ...     ...           ...                  ...
# 5327  Movie       Zinzana      Majid Al Ansari
# 5328  Movie        Zodiac        David Fincher
# 5329  Movie    Zombieland      Ruben Fleischer
# 5330  Movie          Zoom         Peter Hewitt
# 5331  Movie        Zubaan          Mozez Singh
#
#                                                    cast  \
# 2     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 3     Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 5     Adam Sandler, Kevin James, Chris Rock, David S...
# 6     Keri Russell, Josh Hamilton, J.K. Simmons, Dak...
# 7     Liam Hemsworth, Gary Oldman, Amber Heard, Harr...
# ...

# %%
country_label_df=new_df.groupby("country").size().sort_values(ascending=False)[:10].index

# %%
country_value_df=new_df.groupby("country").size().sort_values(ascending=False)[:10].values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=country_value_df,labels=country_label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Top 15 Country with Highest Average duration of movies release

# %%
new_df
# Out:
#        type         title             director  \
# 2     Movie  The Starling       Theodore Melfi
# 3     Movie  Je Suis Karl  Christian Schwochow
# 5     Movie     Grown Ups         Dennis Dugan
# 6     Movie    Dark Skies        Scott Stewart
# 7     Movie      Paranoia       Robert Luketic
# ...     ...           ...                  ...
# 5327  Movie       Zinzana      Majid Al Ansari
# 5328  Movie        Zodiac        David Fincher
# 5329  Movie    Zombieland      Ruben Fleischer
# 5330  Movie          Zoom         Peter Hewitt
# 5331  Movie        Zubaan          Mozez Singh
#
#                                                    cast  \
# 2     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 3     Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 5     Adam Sandler, Kevin James, Chris Rock, David S...
# 6     Keri Russell, Josh Hamilton, J.K. Simmons, Dak...
# 7     Liam Hemsworth, Gary Oldman, Amber Heard, Harr...
# ...

# %%
def ConvertMovieDuration(ele):
    ele=str(ele)
    ele=int(ele.split(" ")[0])
    return ele

# %%
new_df['duration']=new_df['duration'].apply(ConvertMovieDuration)
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_24696\1545246325.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['duration']=new_df['duration'].apply(ConvertMovieDuration)

# %%
new_df
# Out:
#        type         title             director  \
# 2     Movie  The Starling       Theodore Melfi
# 3     Movie  Je Suis Karl  Christian Schwochow
# 5     Movie     Grown Ups         Dennis Dugan
# 6     Movie    Dark Skies        Scott Stewart
# 7     Movie      Paranoia       Robert Luketic
# ...     ...           ...                  ...
# 5327  Movie       Zinzana      Majid Al Ansari
# 5328  Movie        Zodiac        David Fincher
# 5329  Movie    Zombieland      Ruben Fleischer
# 5330  Movie          Zoom         Peter Hewitt
# 5331  Movie        Zubaan          Mozez Singh
#
#                                                    cast  \
# 2     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 3     Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 5     Adam Sandler, Kevin James, Chris Rock, David S...
# 6     Keri Russell, Josh Hamilton, J.K. Simmons, Dak...
# 7     Liam Hemsworth, Gary Oldman, Amber Heard, Harr...
# ...

# %%
new_df=new_df[['title','country','release_year','duration']]

# %%
new_df
# Out:
#              title                       country  release_year  duration
# 2     The Starling                 United States          2021       104
# 3     Je Suis Karl       Germany, Czech Republic          2021       127
# 5        Grown Ups                 United States          2010       103
# 6       Dark Skies                 United States          2013        97
# 7         Paranoia  United States, India, France          2013       106
# ...            ...                           ...           ...       ...
# 5327       Zinzana  United Arab Emirates, Jordan          2015        96
# 5328        Zodiac                 United States          2007       158
# 5329    Zombieland                 United States          2009        88
# 5330          Zoom                 United States          2006        88
# 5331        Zubaan                         India          2015       111
#
# [4713 rows x 4 columns]

# %%
new_df=new_df.sort_values(by="duration",ascending=False)

# %%
new_df=new_df[:15]

# %%
new_df
# Out:
#                                                   title  \
# 470                                              Lagaan
# 2468                                       Jodhaa Akbar
# 1777                                       The Irishman
# 1495                           Kabhi Khushi Kabhie Gham
# 1427                       No Direction Home: Bob Dylan
# 4996                                 The Gospel of Luke
# 1113                               What's Your Raashee?
# 5046      The Lord of the Rings: The Return of the King
# 3840                             Elephants Dream 4 Hour
# 1494                             Kabhi Alvida Naa Kehna
# 1370  Unbreakable Kimmy Schmidt: Kimmy vs. the Reverend
# 1496                                      Kal Ho Naa Ho
# 1553                                             Aurora
# 1715                                     Dil Chahta Hai
# 1725                                            Lakshya
#
# ...

# %%
sns.barplot(x=new_df['country'],y=new_df['duration'])
plt.xticks(rotation=90)
plt.show()

# %%
new_df
# Out:
#                                                   title  \
# 470                                              Lagaan
# 2468                                       Jodhaa Akbar
# 1777                                       The Irishman
# 1495                           Kabhi Khushi Kabhie Gham
# 1427                       No Direction Home: Bob Dylan
# 4996                                 The Gospel of Luke
# 1113                               What's Your Raashee?
# 5046      The Lord of the Rings: The Return of the King
# 3840                             Elephants Dream 4 Hour
# 1494                             Kabhi Alvida Naa Kehna
# 1370  Unbreakable Kimmy Schmidt: Kimmy vs. the Reverend
# 1496                                      Kal Ho Naa Ho
# 1553                                             Aurora
# 1715                                     Dil Chahta Hai
# 1725                                            Lakshya
#
# ...

# %%
df
# Out:
#          type                          title             director  \
# 1     TV Show  The Great British Baking Show      Andy Devonshire
# 2       Movie                   The Starling       Theodore Melfi
# 3       Movie                   Je Suis Karl  Christian Schwochow
# 5       Movie                      Grown Ups         Dennis Dugan
# 6       Movie                     Dark Skies        Scott Stewart
# ...       ...                            ...                  ...
# 5327    Movie                        Zinzana      Majid Al Ansari
# 5328    Movie                         Zodiac        David Fincher
# 5329    Movie                     Zombieland      Ruben Fleischer
# 5330    Movie                           Zoom         Peter Hewitt
# 5331    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# 1     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 2     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# ...

# %% [markdown]
# # Maximum Movies are director by which director?

# %%
label_df=df['director'].value_counts().sort_values(ascending=False)[:10].index

# %%
value_df=df['director'].value_counts().sort_values(ascending=False)[:10].values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Direcotor Marcus Raboy Anslysis

# %%
df
# Out:
#          type                          title             director  \
# 1     TV Show  The Great British Baking Show      Andy Devonshire
# 2       Movie                   The Starling       Theodore Melfi
# 3       Movie                   Je Suis Karl  Christian Schwochow
# 5       Movie                      Grown Ups         Dennis Dugan
# 6       Movie                     Dark Skies        Scott Stewart
# ...       ...                            ...                  ...
# 5327    Movie                        Zinzana      Majid Al Ansari
# 5328    Movie                         Zodiac        David Fincher
# 5329    Movie                     Zombieland      Ruben Fleischer
# 5330    Movie                           Zoom         Peter Hewitt
# 5331    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# 1     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 2     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# ...

# %%
Marcus_Raboy_df=df.groupby("director").get_group("Marcus Raboy")

# %%
Marcus_Raboy_df
# Out:
#          type                                              title  \
# 1349  TV Show                   Patton Oswalt: I Love Everything
# 1559    Movie              Taylor Tomlinson: Quarter-Life Crisis
# 2032    Movie                    Miranda Sings Live…Your Welcome
# 2075    Movie       Anthony Jeselnik: Fire in the Maternity Ward
# 2310    Movie                                 Vir Das: Losing It
# 2604    Movie                       Katt Williams: Kattpacalypse
# 2644    Movie  Steve Martin and Martin Short: An Evening You ...
# 2757    Movie                            Marlon Wayans: Woke-ish
# 2817    Movie                            Judd Apatow: The Return
# 2840    Movie                      DeRay Davis: How to Act Black
# 2917    Movie                          Ryan Hamilton: Happy Face
# 2921    Movie                      Lynne Koplitz: Hormonal Beast
# 3037    Movie                      Vir Das: Abroad Understanding
# ...

# %%
Marcus_Raboy_df=Marcus_Raboy_df[Marcus_Raboy_df['type']=="Movie"]

# %%
Marcus_Raboy_df
# Out:
#        type                                              title      director  \
# 1559  Movie              Taylor Tomlinson: Quarter-Life Crisis  Marcus Raboy
# 2032  Movie                    Miranda Sings Live…Your Welcome  Marcus Raboy
# 2075  Movie       Anthony Jeselnik: Fire in the Maternity Ward  Marcus Raboy
# 2310  Movie                                 Vir Das: Losing It  Marcus Raboy
# 2604  Movie                       Katt Williams: Kattpacalypse  Marcus Raboy
# 2644  Movie  Steve Martin and Martin Short: An Evening You ...  Marcus Raboy
# 2757  Movie                            Marlon Wayans: Woke-ish  Marcus Raboy
# 2817  Movie                            Judd Apatow: The Return  Marcus Raboy
# 2840  Movie                      DeRay Davis: How to Act Black  Marcus Raboy
# 2917  Movie                          Ryan Hamilton: Happy Face  Marcus Raboy
# 2921  Movie                      Lynne Koplitz: Hormonal Beast  Marcus Raboy
# ...

# %%
Marcus_Raboy_df['duration']=Marcus_Raboy_df['duration'].apply(ConvertMovieDuration)
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_24696\1049432948.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Marcus_Raboy_df['duration']=Marcus_Raboy_df['duration'].apply(ConvertMovieDuration)

# %%
Marcus_Raboy_df
# Out:
#        type                                              title      director  \
# 1559  Movie              Taylor Tomlinson: Quarter-Life Crisis  Marcus Raboy
# 2032  Movie                    Miranda Sings Live…Your Welcome  Marcus Raboy
# 2075  Movie       Anthony Jeselnik: Fire in the Maternity Ward  Marcus Raboy
# 2310  Movie                                 Vir Das: Losing It  Marcus Raboy
# 2604  Movie                       Katt Williams: Kattpacalypse  Marcus Raboy
# 2644  Movie  Steve Martin and Martin Short: An Evening You ...  Marcus Raboy
# 2757  Movie                            Marlon Wayans: Woke-ish  Marcus Raboy
# 2817  Movie                            Judd Apatow: The Return  Marcus Raboy
# 2840  Movie                      DeRay Davis: How to Act Black  Marcus Raboy
# 2917  Movie                          Ryan Hamilton: Happy Face  Marcus Raboy
# 2921  Movie                      Lynne Koplitz: Hormonal Beast  Marcus Raboy
# ...

# %%
sns.countplot(Marcus_Raboy_df['Year_added'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Year_added', ylabel='count'>

# %%
sns.countplot(Marcus_Raboy_df['Month_added'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Month_added', ylabel='count'>

# %%
sns.countplot(Marcus_Raboy_df['Day_of_week_added'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Day_of_week_added', ylabel='count'>

# %%
sns.countplot(Marcus_Raboy_df['rating'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='rating', ylabel='count'>

# %%
sns.countplot(Marcus_Raboy_df['cast'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(Marcus_Raboy_df['quarter'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lineplot(x=Marcus_Raboy_df['release_year'],y=Marcus_Raboy_df['duration'])
# Out:
# <AxesSubplot:xlabel='release_year', ylabel='duration'>

# %% [markdown]
# # Year in which highest Movies and TV Show was added

# %%
df
# Out:
#          type                          title             director  \
# 1     TV Show  The Great British Baking Show      Andy Devonshire
# 2       Movie                   The Starling       Theodore Melfi
# 3       Movie                   Je Suis Karl  Christian Schwochow
# 5       Movie                      Grown Ups         Dennis Dugan
# 6       Movie                     Dark Skies        Scott Stewart
# ...       ...                            ...                  ...
# 5327    Movie                        Zinzana      Majid Al Ansari
# 5328    Movie                         Zodiac        David Fincher
# 5329    Movie                     Zombieland      Ruben Fleischer
# 5330    Movie                           Zoom         Peter Hewitt
# 5331    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# 1     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 2     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# ...

# %%
label_df=df.groupby("Year_added").size().sort_values(ascending=False).index

# %%
value_df=df.groupby("Year_added").size().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Month in which highest Movies and TV Show was added

# %%
df
# Out:
#          type                          title             director  \
# 1     TV Show  The Great British Baking Show      Andy Devonshire
# 2       Movie                   The Starling       Theodore Melfi
# 3       Movie                   Je Suis Karl  Christian Schwochow
# 5       Movie                      Grown Ups         Dennis Dugan
# 6       Movie                     Dark Skies        Scott Stewart
# ...       ...                            ...                  ...
# 5327    Movie                        Zinzana      Majid Al Ansari
# 5328    Movie                         Zodiac        David Fincher
# 5329    Movie                     Zombieland      Ruben Fleischer
# 5330    Movie                           Zoom         Peter Hewitt
# 5331    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# 1     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 2     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# ...

# %%
label_df=df.groupby("Month_added").size().sort_values(ascending=False).index

# %%
value_df=df.groupby("Month_added").size().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Indian Country Movie Analysis

# %%
india_df=df.groupby("country").get_group("India")

# %%
india_df
# Out:
#        type                  title                 director  \
# 33    Movie       Angamaly Diaries     Lijo Jose Pellissery
# 37    Movie                 Dhanak          Nagesh Kukunoor
# 38    Movie                Gurgaon            Shanker Raman
# 40    Movie                Shikara       Vidhu Vinod Chopra
# 88    Movie             Thimmarusu        Sharan Koppisetty
# ...     ...                    ...                      ...
# 5307  Movie  Yamla Pagla Deewana 2           Sangeeth Sivan
# 5308  Movie    Yanda Kartavya Aahe             Kedar Shinde
# 5325  Movie               Zed Plus  Chandra Prakash Dwivedi
# 5326  Movie                  Zenda           Avadhoot Gupte
# 5331  Movie                 Zubaan              Mozez Singh
#
#                                                    cast country  release_year  \
# 33    Antony Varghese, Reshma Rajan, Binny Rinky Ben...   India          2017
# 37    Krrish Chhabria, Hetal Gada, Vipin Sharma, Gul...   India          2015
# ...

# %%
sns.countplot(india_df['type'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
indian_movie_df=india_df.groupby("type").get_group("Movie")

# %%
indian_movie_df
# Out:
#        type                  title                 director  \
# 33    Movie       Angamaly Diaries     Lijo Jose Pellissery
# 37    Movie                 Dhanak          Nagesh Kukunoor
# 38    Movie                Gurgaon            Shanker Raman
# 40    Movie                Shikara       Vidhu Vinod Chopra
# 88    Movie             Thimmarusu        Sharan Koppisetty
# ...     ...                    ...                      ...
# 5307  Movie  Yamla Pagla Deewana 2           Sangeeth Sivan
# 5308  Movie    Yanda Kartavya Aahe             Kedar Shinde
# 5325  Movie               Zed Plus  Chandra Prakash Dwivedi
# 5326  Movie                  Zenda           Avadhoot Gupte
# 5331  Movie                 Zubaan              Mozez Singh
#
#                                                    cast country  release_year  \
# 33    Antony Varghese, Reshma Rajan, Binny Rinky Ben...   India          2017
# 37    Krrish Chhabria, Hetal Gada, Vipin Sharma, Gul...   India          2015
# ...

# %%
indian_movie_df['duration'].unique()
# Out:
# array(['128 min', '114 min', '106 min', '115 min', '125 min', '127 min',
#        '135 min', '124 min', '136 min', '165 min', '150 min', '112 min',
#        '119 min', '133 min', '142 min', '93 min', '113 min', '116 min',
#        '145 min', '143 min', '64 min', '68 min', '105 min', '131 min',
#        '140 min', '81 min', '99 min', '107 min', '122 min', '98 min',
#        '149 min', '101 min', '102 min', '147 min', '141 min', '109 min',
#        '162 min', '91 min', '164 min', '121 min', '151 min', '120 min',
#        '97 min', '104 min', '96 min', '161 min', '129 min', '148 min',
#        '50 min', '171 min', '130 min', '108 min', '75 min', '117 min',
#        '156 min', '126 min', '146 min', '137 min', '139 min', '111 min',
#        '103 min', '157 min', '138 min', '110 min', '203 min', '123 min',
#        '95 min', '86 min', '166 min', '94 min', '132 min', '92 min',
#        '83 min', '72 min', '144 min', '87 min', '192 min', '209 min',
# ...

# %%
indian_movie_df['duration']=indian_movie_df['duration'].apply(ConvertMovieDuration)
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_24696\4025344874.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   indian_movie_df['duration']=indian_movie_df['duration'].apply(ConvertMovieDuration)

# %%
indian_movie_df
# Out:
#        type                  title                 director  \
# 33    Movie       Angamaly Diaries     Lijo Jose Pellissery
# 37    Movie                 Dhanak          Nagesh Kukunoor
# 38    Movie                Gurgaon            Shanker Raman
# 40    Movie                Shikara       Vidhu Vinod Chopra
# 88    Movie             Thimmarusu        Sharan Koppisetty
# ...     ...                    ...                      ...
# 5307  Movie  Yamla Pagla Deewana 2           Sangeeth Sivan
# 5308  Movie    Yanda Kartavya Aahe             Kedar Shinde
# 5325  Movie               Zed Plus  Chandra Prakash Dwivedi
# 5326  Movie                  Zenda           Avadhoot Gupte
# 5331  Movie                 Zubaan              Mozez Singh
#
#                                                    cast country  release_year  \
# 33    Antony Varghese, Reshma Rajan, Binny Rinky Ben...   India          2017
# 37    Krrish Chhabria, Hetal Gada, Vipin Sharma, Gul...   India          2015
# ...

# %%
indian_movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 781 entries, 33 to 5331
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   type               781 non-null    object
#  1   title              781 non-null    object
#  2   director           781 non-null    object
#  3   cast               781 non-null    object
#  4   country            781 non-null    object
#  5   release_year       781 non-null    int64
#  6   rating             781 non-null    object
#  7   duration           781 non-null    int64
#  8   listed_in          781 non-null    object
#  9   description        781 non-null    object
#  10  Month_added        781 non-null    int64
#  11  Year_added         781 non-null    int64
#  12  Day_added          781 non-null    int64
#  13  Day_of_week_added  781 non-null    int64
#  14  quarter            781 non-null    period[Q-DEC]
# dtypes: int64(6), object(8), period[Q-DEC](1)
# ...

# %%
mean_val=indian_movie_df['duration'].mean()

# %%
mean_val
# Out:
# 125.23431498079385

# %%
sns.lineplot(x=indian_movie_df['release_year'],y=indian_movie_df['duration'])
# Out:
# <AxesSubplot:xlabel='release_year', ylabel='duration'>

# %% [markdown]
# # Average Duration of Movie in India is 125.23 minutes

# %%
indian_movie_df
# Out:
#        type                  title                 director  \
# 33    Movie       Angamaly Diaries     Lijo Jose Pellissery
# 37    Movie                 Dhanak          Nagesh Kukunoor
# 38    Movie                Gurgaon            Shanker Raman
# 40    Movie                Shikara       Vidhu Vinod Chopra
# 88    Movie             Thimmarusu        Sharan Koppisetty
# ...     ...                    ...                      ...
# 5307  Movie  Yamla Pagla Deewana 2           Sangeeth Sivan
# 5308  Movie    Yanda Kartavya Aahe             Kedar Shinde
# 5325  Movie               Zed Plus  Chandra Prakash Dwivedi
# 5326  Movie                  Zenda           Avadhoot Gupte
# 5331  Movie                 Zubaan              Mozez Singh
#
#                                                    cast country  release_year  \
# 33    Antony Varghese, Reshma Rajan, Binny Rinky Ben...   India          2017
# 37    Krrish Chhabria, Hetal Gada, Vipin Sharma, Gul...   India          2015
# ...

# %%
sns.countplot(indian_movie_df['release_year'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(15,10))
sns.countplot(indian_movie_df['listed_in'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(indian_movie_df['rating'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(indian_movie_df['Month_added'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Month_added', ylabel='count'>

# %%
sns.countplot(indian_movie_df['Year_added'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Year_added', ylabel='count'>

# %%
sns.countplot(indian_movie_df['Day_added'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Day_added', ylabel='count'>

# %%
sns.countplot(indian_movie_df['Day_of_week_added'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Day_of_week_added', ylabel='count'>

# %%
sns.countplot(indian_movie_df['quarter'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Top 10 Indian Movie with highest Duration

# %%
indian_movie_df
# Out:
#        type                  title                 director  \
# 33    Movie       Angamaly Diaries     Lijo Jose Pellissery
# 37    Movie                 Dhanak          Nagesh Kukunoor
# 38    Movie                Gurgaon            Shanker Raman
# 40    Movie                Shikara       Vidhu Vinod Chopra
# 88    Movie             Thimmarusu        Sharan Koppisetty
# ...     ...                    ...                      ...
# 5307  Movie  Yamla Pagla Deewana 2           Sangeeth Sivan
# 5308  Movie    Yanda Kartavya Aahe             Kedar Shinde
# 5325  Movie               Zed Plus  Chandra Prakash Dwivedi
# 5326  Movie                  Zenda           Avadhoot Gupte
# 5331  Movie                 Zubaan              Mozez Singh
#
#                                                    cast country  release_year  \
# 33    Antony Varghese, Reshma Rajan, Binny Rinky Ben...   India          2017
# 37    Krrish Chhabria, Hetal Gada, Vipin Sharma, Gul...   India          2015
# ...

# %%
movie_duration_df=indian_movie_df[['title','director','duration']]

# %%
movie_duration_df
# Out:
#                       title                 director  duration
# 33         Angamaly Diaries     Lijo Jose Pellissery       128
# 37                   Dhanak          Nagesh Kukunoor       114
# 38                  Gurgaon            Shanker Raman       106
# 40                  Shikara       Vidhu Vinod Chopra       115
# 88               Thimmarusu        Sharan Koppisetty       125
# ...                     ...                      ...       ...
# 5307  Yamla Pagla Deewana 2           Sangeeth Sivan       147
# 5308    Yanda Kartavya Aahe             Kedar Shinde       151
# 5325               Zed Plus  Chandra Prakash Dwivedi       131
# 5326                  Zenda           Avadhoot Gupte       120
# 5331                 Zubaan              Mozez Singh       111
#
# [781 rows x 3 columns]

# %%
new_df=movie_duration_df.sort_values(by="duration",ascending=False)

# %%
new_df
# Out:
#                                               title  \
# 2468                                   Jodhaa Akbar
# 1495                       Kabhi Khushi Kabhie Gham
# 1113                           What's Your Raashee?
# 1494                         Kabhi Alvida Naa Kehna
# 1496                                  Kal Ho Naa Ho
# ...                                             ...
# 2948  Aditi Mittal: Things They Wouldn't Let Me Say
# 4842                     Super Bheem Bana Vajraveer
# 4682                  Saeed Mirza: The Leftist Sufi
# 773      Vir Das: Outside In - The Lockdown Special
# 4180                                          Kalki
#
#                                         director  duration
# 2468                          Ashutosh Gowariker       214
# 1495                                 Karan Johar       209
# 1113                          Ashutosh Gowariker       203
# 1494                                 Karan Johar       192
# ...

# %%
sns.barplot(x=new_df['title'][:10],y=new_df['duration'][:10])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Top 10 Indian Movie with lowest Duration

# %%
movie_duration_df
# Out:
#                       title                 director  duration
# 33         Angamaly Diaries     Lijo Jose Pellissery       128
# 37                   Dhanak          Nagesh Kukunoor       114
# 38                  Gurgaon            Shanker Raman       106
# 40                  Shikara       Vidhu Vinod Chopra       115
# 88               Thimmarusu        Sharan Koppisetty       125
# ...                     ...                      ...       ...
# 5307  Yamla Pagla Deewana 2           Sangeeth Sivan       147
# 5308    Yanda Kartavya Aahe             Kedar Shinde       151
# 5325               Zed Plus  Chandra Prakash Dwivedi       131
# 5326                  Zenda           Avadhoot Gupte       120
# 5331                 Zubaan              Mozez Singh       111
#
# [781 rows x 3 columns]

# %%
new_df=movie_duration_df.sort_values(by="duration",ascending=True)

# %%
new_df
# Out:
#                                               title  \
# 4180                                          Kalki
# 773      Vir Das: Outside In - The Lockdown Special
# 4682                  Saeed Mirza: The Leftist Sufi
# 4842                     Super Bheem Bana Vajraveer
# 2948  Aditi Mittal: Things They Wouldn't Let Me Say
# ...                                             ...
# 1496                                  Kal Ho Naa Ho
# 1494                         Kabhi Alvida Naa Kehna
# 1113                           What's Your Raashee?
# 1495                       Kabhi Khushi Kabhie Gham
# 2468                                   Jodhaa Akbar
#
#                                         director  duration
# 4180                                Dhilip Kumar        41
# 773                                      Vir Das        50
# 4682  Kireet Khurana, Padmakumar Narasimhamurthy        61
# 4842                                   Sumit Das        63
# ...

# %%
sns.barplot(x=new_df['title'][:10],y=new_df['duration'][:10])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Year in which highest Indian Movies was added

# %%
indian_movie_df
# Out:
#        type                  title                 director  \
# 33    Movie       Angamaly Diaries     Lijo Jose Pellissery
# 37    Movie                 Dhanak          Nagesh Kukunoor
# 38    Movie                Gurgaon            Shanker Raman
# 40    Movie                Shikara       Vidhu Vinod Chopra
# 88    Movie             Thimmarusu        Sharan Koppisetty
# ...     ...                    ...                      ...
# 5307  Movie  Yamla Pagla Deewana 2           Sangeeth Sivan
# 5308  Movie    Yanda Kartavya Aahe             Kedar Shinde
# 5325  Movie               Zed Plus  Chandra Prakash Dwivedi
# 5326  Movie                  Zenda           Avadhoot Gupte
# 5331  Movie                 Zubaan              Mozez Singh
#
#                                                    cast country  release_year  \
# 33    Antony Varghese, Reshma Rajan, Binny Rinky Ben...   India          2017
# 37    Krrish Chhabria, Hetal Gada, Vipin Sharma, Gul...   India          2015
# ...

# %%
label_df=indian_movie_df.groupby("Year_added").size().sort_values(ascending=False).index

# %%
value_df=indian_movie_df.groupby("Year_added").size().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Month in which highest Indian Movies was added

# %%
df
# Out:
#          type                          title             director  \
# 1     TV Show  The Great British Baking Show      Andy Devonshire
# 2       Movie                   The Starling       Theodore Melfi
# 3       Movie                   Je Suis Karl  Christian Schwochow
# 5       Movie                      Grown Ups         Dennis Dugan
# 6       Movie                     Dark Skies        Scott Stewart
# ...       ...                            ...                  ...
# 5327    Movie                        Zinzana      Majid Al Ansari
# 5328    Movie                         Zodiac        David Fincher
# 5329    Movie                     Zombieland      Ruben Fleischer
# 5330    Movie                           Zoom         Peter Hewitt
# 5331    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# 1     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 2     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# ...

# %%
label_df=indian_movie_df.groupby("Month_added").size().sort_values(ascending=False).index

# %%
value_df=indian_movie_df.groupby("Month_added").size().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Analysis for Indian TV Show

# %%
indian_TV_Show_df=india_df.groupby("type").get_group("TV Show")

# %%
# Top 10 Indian Movie with highest Durationindian_TV_Show_df=india_df.groupby("type").get_group("TV Show")

# %%
indian_TV_Show_df
# Out:
#          type                                  title  \
# 131   TV Show                               Navarasa
# 625   TV Show                          Pitta Kathalu
# 759   TV Show                        Paava Kadhaigal
# 1668  TV Show           Jamtara - Sabka Number Ayega
# 2536  TV Show                                  GHOUL
# 3364  TV Show                              7 (Seven)
# 4880  TV Show  Th Eena Meena Deeka Chase Comedy Show
#
#                                                director  \
# 131   Bejoy Nambiar, Priyadarshan, Karthik Narain, V...
# 625   Tharun Bhascker Dhaassyam, B. V. Nandini Reddy...
# 759   Sudha Kongara, Vignesh Shivan, Gautham Vasudev...
# 1668                                    Soumendra Padhi
# 2536                                     Patrick Graham
# 3364                                        Nizar Shafi
# 4880                                      Dheeraj Berry
#
#                                                    cast country  release_year  \
# ...

# %%
sns.countplot(indian_TV_Show_df['release_year'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='release_year', ylabel='count'>

# %%
sns.countplot(indian_TV_Show_df['Month_added'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Month_added', ylabel='count'>

# %%
sns.countplot(indian_TV_Show_df['Year_added'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Year_added', ylabel='count'>

# %%
sns.countplot(indian_TV_Show_df['listed_in'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(indian_TV_Show_df['rating'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(indian_TV_Show_df['Day_of_week_added'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(indian_TV_Show_df['quarter'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Year in which highest TV Show  was added for India Country

# %%
indian_TV_Show_df
# Out:
#          type                                  title  \
# 131   TV Show                               Navarasa
# 625   TV Show                          Pitta Kathalu
# 759   TV Show                        Paava Kadhaigal
# 1668  TV Show           Jamtara - Sabka Number Ayega
# 2536  TV Show                                  GHOUL
# 3364  TV Show                              7 (Seven)
# 4880  TV Show  Th Eena Meena Deeka Chase Comedy Show
#
#                                                director  \
# 131   Bejoy Nambiar, Priyadarshan, Karthik Narain, V...
# 625   Tharun Bhascker Dhaassyam, B. V. Nandini Reddy...
# 759   Sudha Kongara, Vignesh Shivan, Gautham Vasudev...
# 1668                                    Soumendra Padhi
# 2536                                     Patrick Graham
# 3364                                        Nizar Shafi
# 4880                                      Dheeraj Berry
#
#                                                    cast country  release_year  \
# ...

# %%
label_df=indian_TV_Show_df.groupby("Year_added").size().sort_values(ascending=False).index

# %%
value_df=indian_TV_Show_df.groupby("Year_added").size().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Month in which highest TV Show  was added for India Country

# %%
indian_TV_Show_df
# Out:
#          type                                  title  \
# 131   TV Show                               Navarasa
# 625   TV Show                          Pitta Kathalu
# 759   TV Show                        Paava Kadhaigal
# 1668  TV Show           Jamtara - Sabka Number Ayega
# 2536  TV Show                                  GHOUL
# 3364  TV Show                              7 (Seven)
# 4880  TV Show  Th Eena Meena Deeka Chase Comedy Show
#
#                                                director  \
# 131   Bejoy Nambiar, Priyadarshan, Karthik Narain, V...
# 625   Tharun Bhascker Dhaassyam, B. V. Nandini Reddy...
# 759   Sudha Kongara, Vignesh Shivan, Gautham Vasudev...
# 1668                                    Soumendra Padhi
# 2536                                     Patrick Graham
# 3364                                        Nizar Shafi
# 4880                                      Dheeraj Berry
#
#                                                    cast country  release_year  \
# ...

# %%
label_df=indian_TV_Show_df.groupby("Month_added").size().sort_values(ascending=False).index

# %%
value_df=indian_TV_Show_df.groupby("Month_added").size().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
df
# Out:
#          type                          title             director  \
# 1     TV Show  The Great British Baking Show      Andy Devonshire
# 2       Movie                   The Starling       Theodore Melfi
# 3       Movie                   Je Suis Karl  Christian Schwochow
# 5       Movie                      Grown Ups         Dennis Dugan
# 6       Movie                     Dark Skies        Scott Stewart
# ...       ...                            ...                  ...
# 5327    Movie                        Zinzana      Majid Al Ansari
# 5328    Movie                         Zodiac        David Fincher
# 5329    Movie                     Zombieland      Ruben Fleischer
# 5330    Movie                           Zoom         Peter Hewitt
# 5331    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# 1     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 2     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# ...

# %% [markdown]
# # Maximum Movies are listed_in which type?

# %%
movie_df=df.groupby("type").get_group("Movie")

# %%
movie_df
# Out:
#        type         title             director  \
# 2     Movie  The Starling       Theodore Melfi
# 3     Movie  Je Suis Karl  Christian Schwochow
# 5     Movie     Grown Ups         Dennis Dugan
# 6     Movie    Dark Skies        Scott Stewart
# 7     Movie      Paranoia       Robert Luketic
# ...     ...           ...                  ...
# 5327  Movie       Zinzana      Majid Al Ansari
# 5328  Movie        Zodiac        David Fincher
# 5329  Movie    Zombieland      Ruben Fleischer
# 5330  Movie          Zoom         Peter Hewitt
# 5331  Movie        Zubaan          Mozez Singh
#
#                                                    cast  \
# 2     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 3     Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 5     Adam Sandler, Kevin James, Chris Rock, David S...
# 6     Keri Russell, Josh Hamilton, J.K. Simmons, Dak...
# 7     Liam Hemsworth, Gary Oldman, Amber Heard, Harr...
# ...

# %%
label_df=movie_df.groupby("listed_in").size().sort_values(ascending=False)[:15].index

# %%
value_df=movie_df.groupby("listed_in").size().sort_values(ascending=False)[:15].values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Maximum Movies are given what rating?

# %%
label_df=movie_df.groupby("rating").size().sort_values(ascending=False).index

# %%
value_df=movie_df.groupby("rating").size().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
df
# Out:
#          type                          title             director  \
# 1     TV Show  The Great British Baking Show      Andy Devonshire
# 2       Movie                   The Starling       Theodore Melfi
# 3       Movie                   Je Suis Karl  Christian Schwochow
# 5       Movie                      Grown Ups         Dennis Dugan
# 6       Movie                     Dark Skies        Scott Stewart
# ...       ...                            ...                  ...
# 5327    Movie                        Zinzana      Majid Al Ansari
# 5328    Movie                         Zodiac        David Fincher
# 5329    Movie                     Zombieland      Ruben Fleischer
# 5330    Movie                           Zoom         Peter Hewitt
# 5331    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# 1     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 2     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# ...

# %% [markdown]
# #
